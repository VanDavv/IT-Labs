# %%
import math
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
fs = 10000  # hz
T = 4  # s

# %%
size = int(T * fs)

# %%
def g(n, H):
    t = n / fs
    return (9 / math.pi ** 2) * sum([math.sin((i * t * math.pi) / 2) * math.sin(20 * n * math.pi * t) for i in range(1, H + 1)])

# %%
result_3 = [g(i, 3) for i in range(size)]
result_3
# Out:
# [0.0,
#  5.3999643362555085e-06,
#  4.319544796670527e-05,
#  0.00014572227469382626,
#  0.000345018024932513,
#  0.0006722271816257243,
#  0.0011564780990939408,
#  0.0018230752051765719,
#  0.002690882869403663,
#  0.0037688381967327885,
#  0.0050516296680430854,
#  0.0065147271659747935,
#  0.008109152743099856,
#  0.009756638663840363,
#  0.011346114472584894,
#  0.012732763324716729,
#  0.01374112983377028,
#  0.014173859619680637,
#  0.013827491569853183,
#  0.012516180593980665,
#  0.010103184549875714,
#  0.006538336457445197,
#  0.0018975772248170212,
#  -0.003581855537620328,
#  -0.009479380366297889,
#  -0.015192603543881236,
#  -0.01997286990801836,
#  -0.023002672339254418,
#  -0.023516747428538418,
#  -0.02095898536379807,
#  -0.015154589860702146,
#  -0.006463305839160256,
#  0.004131395884864667,
#  0.01504564138035265,
#  0.024270023877573606,
#  0.029709048037524097,
#  0.029655448337952243,
#  0.02331611473245422,
#  0.01125515239236654,
#  -0.004409612775603106,
# ...

# %%
plt.scatter(list(range(size)), result_3)

# %%
result_6 = [g(i, 6) for i in range(size)]
result_6
# Out:
# [0.0,
#  1.8899874011054983e-05,
#  0.0001511840305802978,
#  0.0005100276782786416,
#  0.0012075618954471682,
#  0.0023527915073859717,
#  0.004047664358324745,
#  0.00638074393185609,
#  0.009418052861829639,
#  0.013190867780336242,
#  0.017680594774891333,
#  0.022801374893123595,
#  0.02838178249404292,
#  0.034147879337116924,
#  0.039710920534492995,
#  0.04456405312027432,
#  0.0480931949526671,
#  0.04960762430428002,
#  0.04839525325615292,
#  0.043805656586735735,
#  0.03536027343000684,
#  0.02288355508585828,
#  0.00664132200245148,
#  -0.012536085302747394,
#  -0.03317665246771564,
#  -0.05317206239923212,
#  -0.06990212974019812,
#  -0.08050573286280717,
#  -0.08230463552815594,
#  -0.07335264331472567,
#  -0.05303811990810889,
#  -0.02262022947084948,
#  0.014458972249660015,
#  0.052656207487596494,
#  0.08493902645201651,
#  0.10397381103009576,
#  0.10378577169882394,
#  0.08159951034624605,
#  0.03938952460847145,
#  -0.015432196727460469,
# ...

# %%
plt.scatter(list(range(size)), result_6)

# %%
result_60 = [g(i, 60) for i in range(size)]
result_60
# Out:
# [0.0,
#  0.0016469767686953,
#  0.013174216348837652,
#  0.04444229344541739,
#  0.10521786903566514,
#  0.20499084567275802,
#  0.35263058310122347,
#  0.5558335991232478,
#  0.8203253581901094,
#  1.1487974170666173,
#  1.5395916959782732,
#  1.985189027774617,
#  2.4706212633201825,
#  2.9720044544698685,
#  3.455480259338815,
#  3.8769430492078625,
#  4.183002996642378,
#  4.313664006628643,
#  4.207145395307476,
#  3.8071093061479595,
#  3.072236834423844,
#  1.9876047431384447,
#  0.576662942466773,
#  -1.0881379228215906,
#  -2.8787410120645007,
#  -4.612061423713144,
#  -6.060899041694703,
#  -6.977535158882337,
#  -7.130526891802628,
#  -6.3522665023737215,
#  -4.591030642106928,
#  -1.957139208981481,
#  1.2504268371781209,
#  4.55155816293832,
#  7.338392965978577,
#  8.978304220383942,
#  8.957325243778309,
#  7.038688545125553,
#  3.395799998160586,
#  -1.3296574752629453,
#  -6.089151631674975,
#  -9.63021003150166,
#  -10.82200249493888,
#  -9.03353595473701,
# ...

# %%
plt.scatter(list(range(size)), result_60)
